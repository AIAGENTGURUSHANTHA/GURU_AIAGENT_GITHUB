# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Welcome to September Data Science Bootcamp")
# Out:
# Welcome to September Data Science Bootcamp

# %%
print(10)
print(10 + 20)
print(10 * 20)
# Out:
# 10
# 30
# 200

# %%
print("Python") # string
print(10)  # integer
print(10.5) # floating point/Decimal values
print(True) # Boolean values
# Out:
# Python
# 10
# 10.5
# True

# %%
# Python Syntax
# It is a rule which is used to write a valid code
# python syntax is very easy

# %%
print("Hello"
# Here ) braces is missing
# Out:
#   Cell In[10], line 1
#     print("Hello"
#                  ^
# _IncompleteInputError: incomplete input
